# %% [markdown]
# # Quickstart Overview\n\nThis notebook gives a minimal tour of the project structure and common commands.

# %% [markdown]
# ## 1) Install dependencies\n```bash\nuv sync\n```

# %% [markdown]
# ## 2) Run a baseline workflow\n```bash\nuv run snakemake --workflow-profile workflow/profiles/local --configfile configs/nlp_baseline.yaml\n```

# %%
from pathlib import Path\n\nroot = Path('..').resolve()\ntop_level = sorted([p.name for p in root.iterdir() if not p.name.startswith('.')])\ntop_level[:20]

# %% [markdown]
# ## 3) Inspect available experiment configs

# %%
configs = sorted((root / 'configs').glob('*.yaml'))\n[p.name for p in configs]

# %% [markdown]
# ## 4) Suggested next reads\n- `notebooks/quarto/guide.qmd`\n- `workflow/rules/train.smk`\n- `src/core/trainer.py`
